# %%
import pandas as pd
from itertools import cycle
from IPython.display import clear_output
import os
path_output = 'data/results/all.gff'
path_blast = 'data/results/'
pd.set_option('display.max_colwidth', -1)

# %%
#TEs
params = {}
params['LTR'] = {'file':'blast_clustered_ltr.csv.filtered'}
params['LINE'] = {'file':'blast_clustered_line.csv.filtered'}
params['SINE'] = {'file':'blast_clustered_sine.csv.filtered'}
params['TIR'] = {'file':'blast_clustered_tir.csv.filtered'}
params['MITE'] = {'file':'blast_clustered_mite.csv.filtered'}
params['LARD'] = {'file':'blast_clustered_lard.csv.filtered'}
params['helitron'] = {'file':'blast_clustered_helitron.csv.filtered'}
params['TRIM'] = {'file':'blast_clustered_trim.csv.filtered'}

# %%
#read blast output
dfs = []
for k,v in params.items():
    df = pd.read_csv(path_blast + v['file'], sep='\t')
    dfs.append(df)
df_all = pd.concat(dfs)
df_all.columns = ['qseqid','sseqid','qstart','qend','sstart','send','score','length','mismatch','gaps','gapopen','nident','pident','qlen','slen','qcovs']
df_all = df_all.reset_index(drop=True)
print('initial:',len(df_all.index))
# Out:
# ('initial:', 250784)

# %%
df_all.head()
# Out:
#                                                                                                                          qseqid  \
# 0  TRIM_id_2885_RLX_family7_TRIM_retrotransposon1_ChrUn_66754_67889[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 1  TRIM_id_6098_RLX_family2_TRIM_retrotransposon2_ChrUn_69446_70736[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 2  TRIM_id_3079_RLX_family2_TRIM_retrotransposon710_chr00_17950287_17951281[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 3  TRIM_id_496_RLX_family96_TRIM_retrotransposon709_chr00_17949413_17950254[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 4  TRIM_id_6327_RLX_family30_TRIM_retrotransposon1221_chr00_37873552_37874590[type:TRIM_source:tephra][type:TRIM_source:tephra]
#
#   sseqid  qstart  qend  sstart    send  score  length  mismatch  gaps  \
# 0  ChrUn  1       1136  66754   67889   2272   1136    0         0
# 1  ChrUn  1       1291  69446   70736   2542   1291    0         0
# 2  ChrUn  148     993   95047   95894   1304   851     66        8
# 3  ChrUn  1       840   96589   97422   1234   841     76        8
# 4  ChrUn  69      961   100118  101003  1592   893     28        7
#
#    gapopen  nident  pident  qlen       slen  qcovs
# 0  0        1136    100.00  1136  111078864  100
# 1  0        1291    100.00  1291  111078864  100
# 2  7        777     91.30   995   111078864  100
# 3  7        757     90.01   842   111078864  100
# 4  5        858     96.08   1039  111078864  100

# %%
df_all['source'] = 'ST_annotation'
df_all['frame'] = '.'
df_all['score'] = '.'
df_all['strand'] = '+'
df_all['feature'] = 'TE'
splited_id = df_all['qseqid'].str.split('_')
df_all['id_1'] = splited_id.str[0] + '_' + splited_id.str[1] + ':' + splited_id.str[2] + ";source_name:" + splited_id.str[3:].apply(lambda x: '_'.join(x)).str.split('[').str[0] 
df_all['id_2'] = '[' + df_all['qseqid'].str.split('[', 1).str[1]
#df_all['qseqid'] = df_all['qseqid'].str.split('[', 1).str[1] + ';source_id:' + df_all['qseqid'].str.split('[', 1).str[0] 
#df_all['qseqid'] = df_all['qseqid'].str.replace("\\]\\[",";")
#df_all['qseqid'] = df_all['qseqid'].str.replace("]","")
#df_all['qseqid'] = df_all['qseqid'].str.replace("[","")
#df_all['qseqid'] = df_all['qseqid'].str.replace("[","")

# %%
df_all.head()
# Out:
#                                                                                                                          qseqid  \
# 0  TRIM_id_2885_RLX_family7_TRIM_retrotransposon1_ChrUn_66754_67889[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 1  TRIM_id_6098_RLX_family2_TRIM_retrotransposon2_ChrUn_69446_70736[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 2  TRIM_id_3079_RLX_family2_TRIM_retrotransposon710_chr00_17950287_17951281[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 3  TRIM_id_496_RLX_family96_TRIM_retrotransposon709_chr00_17949413_17950254[type:TRIM_source:tephra][type:TRIM_source:tephra]
# 4  TRIM_id_6327_RLX_family30_TRIM_retrotransposon1221_chr00_37873552_37874590[type:TRIM_source:tephra][type:TRIM_source:tephra]
#
#   sseqid  qstart  qend  sstart    send score  length  mismatch  gaps  \
# 0  ChrUn  1       1136  66754   67889   .     1136    0         0
# 1  ChrUn  1       1291  69446   70736   .     1291    0         0
# 2  ChrUn  148     993   95047   95894   .     851     66        8
# 3  ChrUn  1       840   96589   97422   .     841     76        8
# 4  ChrUn  69      961   100118  101003  .     893     28        7
#
#                           ...                          pident  qlen  \
# 0                         ...                          100.00  1136
# 1                         ...                          100.00  1291
# 2                         ...                          91.30   995
# 3                         ...                          90.01   842
# 4                         ...                          96.08   1039
#
#         slen  qcovs         source  frame strand feature  \
# 0  111078864  100    ST_annotation  .      +      TE
# 1  111078864  100    ST_annotation  .      +      TE
# 2  111078864  100    ST_annotation  .      +      TE
# 3  111078864  100    ST_annotation  .      +      TE
# 4  111078864  100    ST_annotation  .      +      TE
#
#                                                                                      id_1  \
# 0  TRIM_id:2885;source_name:RLX_family7_TRIM_retrotransposon1_ChrUn_66754_67889
# 1  TRIM_id:6098;source_name:RLX_family2_TRIM_retrotransposon2_ChrUn_69446_70736
# 2  TRIM_id:3079;source_name:RLX_family2_TRIM_retrotransposon710_chr00_17950287_17951281
# 3  TRIM_id:496;source_name:RLX_family96_TRIM_retrotransposon709_chr00_17949413_17950254
# 4  TRIM_id:6327;source_name:RLX_family30_TRIM_retrotransposon1221_chr00_37873552_37874590
#
#                                                  id_2
# 0  [type:TRIM_source:tephra][type:TRIM_source:tephra]
# 1  [type:TRIM_source:tephra][type:TRIM_source:tephra]
# 2  [type:TRIM_source:tephra][type:TRIM_source:tephra]
# 3  [type:TRIM_source:tephra][type:TRIM_source:tephra]
# 4  [type:TRIM_source:tephra][type:TRIM_source:tephra]
#
# [5 rows x 22 columns]

# %%
#order by chromosome and position
df_all['new_sstart'] = df_all[['sstart','send']].min(axis=1)
df_all['new_ssend'] = df_all[['sstart','send']].max(axis=1)
df_all['sstart'] = df_all['new_sstart']
df_all['send'] = df_all['new_ssend']
df_all = df_all.drop('new_sstart',axis=1).drop('new_ssend',axis=1)
df_all.sort_values(['sseqid', 'sstart'], inplace=True)

# %%
#delete dups annotation
count = 1
for k,v in df_all.iterrows():
    qs = {}
    for q in v.id_2.split("]"):
        qs[q.replace("[","")] = 1
    new_qseqid = ";".join(qs.keys())
    df_all.at[k, 'id_2'] = new_qseqid
    df_all.at[k, 'id_2'] = new_qseqid + ';unique_id:' + str(count)
    count += 1

# %%
df_all['qseqid'] = df_all['id_1'] + df_all['id_2']
df_all = df_all[['sseqid','source','feature','sstart','send','score','strand','frame','qseqid']]
#gff3 -> ['seqname' , 'source' , 'feature' , 'start' , 'end' , 'score' , 'strand' , 'frame' , 'attribute']

# %%
df_all['qseqid'].head()
# Out:
# 13773    LTR_id:4487;source_name:RLG_singleton_family951_LTR_7304_chr04_35766884_35772038;type:ltr;source:tephra;unique_id:1
# 0        TRIM_id:2885;source_name:RLX_family7_TRIM_retrotransposon1_ChrUn_66754_67889;type:TRIM_source:tephra;unique_id:2
# 1        TRIM_id:6098;source_name:RLX_family2_TRIM_retrotransposon2_ChrUn_69446_70736;type:TRIM_source:tephra;unique_id:3
# 13774    LTR_id:3840;source_name:RLG_family25_LTR_19826_chr12_41906734_41909427;type:ltr;source:tephra;unique_id:4
# 13775    LTR_id:2746;source_name:RLG_LTR_569_FAM007127;type:ltr;source:TASR;unique_id:5
# Name: qseqid, dtype: object

# %%
df_all.to_csv(path_output, sep="\t", header=None, index=None)
path_output
# Out:
# 'data/results/all.gff'
